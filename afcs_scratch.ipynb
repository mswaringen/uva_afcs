# %%
library(fpp2)
# Out:
# Registered S3 methods overwritten by 'ggplot2':
#   method         from
#   [.quosures     rlang
#   c.quosures     rlang
#   print.quosures rlang
# Registered S3 method overwritten by 'xts':
#   method     from
#   as.zoo.xts zoo
# Registered S3 method overwritten by 'quantmod':
#   method            from
#   as.zoo.data.frame zoo
# ── Attaching packages ────────────────────────────────────────────── fpp2 2.4 ──
# ✔ ggplot2   3.1.1     ✔ fma       2.4
# ✔ forecast  8.13      ✔ expsmooth 2.3

# %%
options(repr.plot.res = 75)

# %%
autoplot(usnetelec)
# Out:
# plot without title

# %%
autoplot(diff(diff(usnetelec)))
# Out:
# plot without title

# %%
ggAcf(diff(diff(usnetelec)))
# Out:
# plot without title

# %%
usnetelec %>% diff() %>%
  ggAcf()
# Out:
# plot without title

# %%
usnetelec %>% diff() %>%
  autoplot()
# Out:
# plot without title

# %%
autoplot(usgdp)
# Out:
# plot without title

# %%
usgdp %>% diff() %>% diff() %>%
  autoplot()
# Out:
# plot without title

# %%
usgdp %>% diff() %>% diff() %>%
  ggAcf()
# Out:
# plot without title

# %%
gasoline %>% tbats () %>% forecast() %>% autoplot
# Out:
# plot without title

# %%
gasoline %>% auto.arima() %>% forecast() %>% autoplot
# Out:
# plot without title
