# %% [markdown]
# ## Assignment 0

# %%
library(fpp2)
# Out:
# Registered S3 methods overwritten by 'ggplot2':
#   method         from
#   [.quosures     rlang
#   c.quosures     rlang
#   print.quosures rlang
# Registered S3 method overwritten by 'xts':
#   method     from
#   as.zoo.xts zoo
# Registered S3 method overwritten by 'quantmod':
#   method            from
#   as.zoo.data.frame zoo
# ── Attaching packages ────────────────────────────────────────────── fpp2 2.4 ──
# ✔ ggplot2   3.1.1     ✔ fma       2.4
# ✔ forecast  8.13      ✔ expsmooth 2.3

# %%
help(gold)

# %%
frequency(gas)
# Out:
# [1] 12

# %%
max(gold)
# Out:
# [1] NA

# %%
which.max(gold)
# Out:
# [1] 770

# %%
autoplot(gold)
# Out:
# plot without title

# %%
tute1 = read.csv("data/tute1.csv",header=TRUE)

# %%
mts = ts(tute1[,-1],start=1981,frequency=4)

# %%
autoplot(mts,facets=TRUE)
# Out:
# plot without title

# %%
retaildata = readxl::read_excel("data/retail.xlsx",skip=1)

# %%
rts = ts(retaildata[,"A3349873A"],frequency=12,start=c(1982,4))

# %%
autoplot(rts)
# Out:
# plot without title

# %%
ggseasonplot(rts)
# Out:
# plot without title

# %%
ggsubseriesplot(rts)
# Out:
# plot without title

# %%
gglagplot(rts)
# Out:
# plot without title

# %%
ggAcf(rts)
# Out:
# plot without title
