# %% [markdown]
# # AFCS Assignment 1

# %%
library(fpp2)
# Out:
# Registered S3 methods overwritten by 'ggplot2':
#   method         from
#   [.quosures     rlang
#   c.quosures     rlang
#   print.quosures rlang
# Registered S3 method overwritten by 'xts':
#   method     from
#   as.zoo.xts zoo
# Registered S3 method overwritten by 'quantmod':
#   method            from
#   as.zoo.data.frame zoo
# ── Attaching packages ────────────────────────────────────────────── fpp2 2.4 ──
# ✔ ggplot2   3.1.1     ✔ fma       2.4
# ✔ forecast  8.13      ✔ expsmooth 2.3

# %%
library(urca)
library("IRdisplay")

# %%
options(repr.plot.res = 75)

# %% [markdown]
# ## Exercise 1.5

# %% [markdown]
# ### A)
#
# #### wmurders
#
# Annual female murder rate (per 100,000 standard population) in the USA. 1950-2004.
# Description
# Total Murdered women, per 100 000 standard population.
#
# Format
# Annual time series of class ts.
#
# Source
# Gapminder Foundation.

# %%
autoplot(wmurders)
# Out:
# plot without title

# %%
wmurders %>% diff() %>% diff() %>%
  ggtsdisplay()
# Out:
# plot without title

# %% [markdown]
# ### a.1)
# By studying appropriate graphs of the series in R, find an appropriate ARIMA(p, d, q) model for these data.
#
# The appropriate ARIMA model is 1,1,1 for p,d,q, respectively.
#
# - AR(0) is appropriate as there is no exponential decay in ACF
# - D(2) is appropriate as 2 differences are required to quickly reduce ACF, D(1) has ACF decay too slowly
# - MA(1) is appropriate as there is a single significant spike in ACF and there is an element of expoential decay in PACF

# %% [markdown]
# ### a.2)
# Should you include a constant in the model? Explain.
#
# In this case no constant is required as d=2. Adding a constant would create a higher order trend which could be dangerous to the forecast accuracy.

# %% [markdown]
# ### a.3)
# Write this model in terms of the backshift operator.

# %%
display_png(file="data/backshift.png")

# %% [markdown]
# ### a.4)
# Fit the model using R and examine the residuals. Is the model satisfactory?
#
# Yes the model is satisfactory. Test of residuals show a normal distribution, both graphically and with the Ljung-Box test

# %%
(fit <- Arima(wmurders, order=c(0,2,1)))
# Out:
# Series: wmurders
# ARIMA(0,2,1)
#
# Coefficients:
#           ma1
#       -0.8995
# s.e.   0.0669
#
# sigma^2 estimated as 0.04747:  log likelihood=5.24
# AIC=-6.48   AICc=-6.24   BIC=-2.54

# %%
checkresiduals(fit)
# Out:
# 	Ljung-Box test
#
# data:  Residuals from ARIMA(0,2,1)
# Q* = 13.04, df = 9, p-value = 0.1608
#
# Model df: 1.   Total lags used: 10
# plot without title

# %% [markdown]
# ### a.5)
# Forecast three times ahead. Check your forecasts by hand to make sure that you know how they have been calculated.

# %%
forecast(fit,h=3)
# Out:
#      Point Forecast    Lo 80    Hi 80    Lo 95    Hi 95
# 2005       2.504087 2.224876 2.783299 2.077070 2.931105
# 2006       2.418792 2.003603 2.833981 1.783815 3.053769
# 2007       2.333496 1.799788 2.867204 1.517260 3.149732

# %% [markdown]
# ### a.6)
# Create a plot of the series with forecasts and prediction intervals for the next three periods shown.

# %%
autoplot(forecast(fit,h=3))
# Out:
# plot without title

# %% [markdown]
# ### a.7)
# Does auto.arima() give the same model you have chosen? If not, which model do you think is better?
#
# Auto Arima produces a similar model with ARIMA(1,2,1) but with a slightly lower AICc score of -6.39 vs -6.24 for the initial model. Therefore the Auto Arima model is slightly better.

# %%
auto.arima(wmurders)
# Out:
# Series: wmurders
# ARIMA(1,2,1)
#
# Coefficients:
#           ar1      ma1
#       -0.2434  -0.8261
# s.e.   0.1553   0.1143
#
# sigma^2 estimated as 0.04632:  log likelihood=6.44
# AIC=-6.88   AICc=-6.39   BIC=-0.97

# %% [markdown]
# ### B)
#
# #### usgdp
#
# Quarterly US GDP
# Description
# Quarterly US GDP. 1947:1 - 2006.1

# %%
autoplot(usgdp)
# Out:
# plot without title

# %%
(lambda <- BoxCox.lambda(usgdp))
# Out:
# [1] 0.366352

# %% [markdown]
# ### b.1)
# if necessary, find a suitable Box-Cox transformation for the data;

# %%
usgdp %>% log() %>% diff(lag=4) %>% 
    ggtsdisplay()
# Out:
# plot without title

# %% [markdown]
# ### b.2)
# fit a suitable ARIMA model to the transformed data using auto.arima();

# %%
auto.arima(usgdp)
# Out:
# Series: usgdp
# ARIMA(2,2,2)
#
# Coefficients:
#           ar1     ar2      ma1      ma2
#       -0.1228  0.3106  -0.5835  -0.3669
# s.e.   0.2869  0.0872   0.3004   0.2862
#
# sigma^2 estimated as 1604:  log likelihood=-1199.57
# AIC=2409.13   AICc=2409.39   BIC=2426.43

# %% [markdown]
# ### b.3)
# try some other plausible models by experimenting with the orders chosen;

# %%
(fit <- Arima(usgdp, order=c(3,2,1)))
# Out:
# Series: usgdp
# ARIMA(3,2,1)
#
# Coefficients:
#          ar1     ar2      ar3      ma1
#       0.2508  0.2196  -0.0592  -0.9641
# s.e.  0.0670  0.0675   0.0667   0.0163
#
# sigma^2 estimated as 1607:  log likelihood=-1199.73
# AIC=2409.47   AICc=2409.73   BIC=2426.76

# %%
(fit <- Arima(usgdp, order=c(2,2,2)))
# Out:
# Series: usgdp
# ARIMA(2,2,2)
#
# Coefficients:
#           ar1     ar2      ma1      ma2
#       -0.1228  0.3106  -0.5835  -0.3669
# s.e.   0.2869  0.0872   0.3004   0.2862
#
# sigma^2 estimated as 1604:  log likelihood=-1199.57
# AIC=2409.13   AICc=2409.39   BIC=2426.43

# %% [markdown]
# ### b.4)
# choose what you think is the best model and check the residual diagnostics;

# %%
checkresiduals(fit)
# Out:
# 	Ljung-Box test
#
# data:  Residuals from ARIMA(2,2,2)
# Q* = 8.6247, df = 4, p-value = 0.0712
#
# Model df: 4.   Total lags used: 8
# plot without title

# %% [markdown]
# ### b.5)
# produce forecasts of your fitted model. Do the forecasts look reasonable?
#
# The forecast indeed looks reasonable

# %%
autoplot(forecast(fit,h=24))
# Out:
# plot without title

# %% [markdown]
# ### b.6)
# compare the results with what you would obtain using ets() (with no transformation)
#
# The ETS forecast has a similar trend line but wider predicition inverval compared with the Arima model

# %%
usgdp %>% ets() %>% forecast(h=24) %>% autoplot()
# Out:
# plot without title

# %% [markdown]
# ### C)
#
# #### usmelec
#
# Electricity monthly total net generation. January 1973 - June 2013.
# Description
# Electricity net generation measured in billions of kilowatt hours (kWh).
#
# Format
# Time series object of class ts.
#
# Source
# US Energy Information Administration.

# %% [markdown]
# ### c.1)
# Examine the 12-month moving average of this series to see what kind of trend is involved.

# %%
# ma12.ts <- usmelec %>% ts(frequency =12)
# autoplot(ma12.ts)
autoplot(usmelec) +
    autolayer(ma(usmelec,order=13),series="12mo MA",size=2)
# Out:
# Warning message:
# “Removed 12 rows containing missing values (geom_path).”
# plot without title

# %% [markdown]
# ### c.2)
# Do the data need transforming? If so, find a suitable transformation.

# %%
lambda <- BoxCox.lambda(usmelec)
transform_usmelec <- BoxCox(usmelec,lambda)
autoplot(transform_usmelec)
# Out:
# plot without title

# %%
lambda
# Out:
# [1] -0.5738331

# %% [markdown]
# ### c.3)
# Are the data stationary? If not, find an appropriate differencing which yields stationary data

# %%
usmelec %>% diff(lag=12) %>% diff(lag=2) %>% 
    ggtsdisplay()
# Out:
# plot without title

# %% [markdown]
# ### c.4)
# Identify a couple of ARIMA models that might be useful in describing the time series. Which of your models is the best according to their AIC values?
#
# The following model produced the lowest AICc: "ARIMA(1,0,2)(1,0,1)(12)(lamdba=-0.573)"

# %%
(fit <- auto.arima(usmelec))
# Out:
# Series: usmelec
# ARIMA(1,0,2)(0,1,1)[12] with drift
#
# Coefficients:
#          ar1      ma1      ma2     sma1   drift
#       0.9717  -0.4374  -0.2774  -0.7061  0.3834
# s.e.  0.0163   0.0483   0.0493   0.0310  0.0868
#
# sigma^2 estimated as 57.67:  log likelihood=-1635.13
# AIC=3282.26   AICc=3282.44   BIC=3307.22

# %%
(fit <- Arima(usmelec, order=c(1,0,2), seasonal=c(0,1,1),lambda=lambda))
# Out:
# Series: usmelec
# ARIMA(1,0,2)(0,1,1)[12]
# Box Cox transformation: lambda= -0.5738331
#
# Coefficients:
#          ar1      ma1      ma2     sma1
#       0.9987  -0.4311  -0.2545  -0.8528
# s.e.  0.0016   0.0440   0.0441   0.0265
#
# sigma^2 estimated as 1.28e-06:  log likelihood=2550.34
# AIC=-5090.69   AICc=-5090.56   BIC=-5069.88

# %% [markdown]
# ### c.5)
# Estimate the parameters of your best model and do diagnostic testing on the residuals. Do the residuals resemble white noise? If not, try to find another ARIMA model which fits better.
#
# Residual distribution is normal however ACF spikes are near the white noise limit in several instances. Ljung-Box score is also below the p-value threshold and points to non-white noise. However this model had the best score of several tested and we could not find a better solution.

# %%
checkresiduals(fit)
# Out:
# 	Ljung-Box test
#
# data:  Residuals from ARIMA(1,0,2)(0,1,1)[12]
# Q* = 36.332, df = 20, p-value = 0.01406
#
# Model df: 4.   Total lags used: 24
# plot without title

# %% [markdown]
# ### c.6)
# Forecast the next 15 years of electricity generation by the U.S. electric industry. Get the latest figures from the EIA to check the accuracy of your forecasts.
#
# The model forecast had a slightly higher trend than actual but was nicely within the 80% prediction interval

# %%
forecast(fit,h=180)
# Out:
#          Point Forecast    Lo 80    Hi 80    Lo 95    Hi 95
# Jul 2013       399.4601 382.0668 418.1330 373.3369 428.5802
# Aug 2013       397.5681 377.8176 418.9937 367.9802 431.0809
# Sep 2013       337.6515 321.7900 354.7792 313.8629 364.4063
# Oct 2013       313.5966 298.9962 329.3513 291.6956 338.2017
# Nov 2013       305.0658 290.6538 320.6355 283.4535 329.3900
# Dec 2013       341.7415 324.0665 360.9827 315.2853 371.8678
# Jan 2014       351.8243 332.8421 372.5677 323.4378 384.3389
# Feb 2014       311.2786 295.1823 328.8008 287.1853 338.7134
# Jul 2025       425.4681 318.1983 603.0617 277.6840 749.5540
# Aug 2025       422.2741 315.5827 599.1561 275.3194 745.2664
# Sep 2025       356.6480 272.8483 489.4858 240.3777 594.4158
# Oct 2025       330.4532 255.1413 447.7816 225.6545 538.8981
# Nov 2025       321.1737 248.5864 433.7365 220.0872 520.7598
# Dec 2025       361.0276 274.4539 499.9273 241.1479 610.9602
# Jan 2026       372.0007 281.1277 519.4566 246.4005 638.6624
# Feb 2026       327.8454 251.9491 447.1302 222.3901 540.5664
# Mar 2026       335.4758 256.6125 460.5241 226.0598 559.3287
# Apr 2026       312.7587 241.2687 424.3164 213.3060 511.0903
# May 2026       343.5681 261.1633 475.7965 229.4636 581.5102
# Jun 2026       382.4239 285.6586 543.0043 249.1617 675.7784
# Jul 2026       427.4462 313.0205 624.8334 270.8136 794.6325
# Aug 2026       424.2263 310.4642 620.7160 268.5321 789.9634
# Sep 2026       358.1419 268.7662 505.1342 234.8796 625.5782
# Oct 2026       331.7762 251.4601 461.3777 220.6662 565.5698
# Nov 2026       322.4370 245.0461 446.6726 215.2826 546.0378
# Dec 2026       362.5446 270.3120 516.1493 235.5967 643.6143
# Jan 2027       373.5888 276.8191 536.7115 240.6500 673.7497
# Feb 2027       329.1452 248.3136 460.7408 217.4836 567.4760
# Mar 2027       336.8218 252.8642 474.8002 221.0180 587.7738
# Apr 2027       313.9622 237.8593 436.8634 208.6945 535.7472
# May 2027       344.9619 257.2959 490.8585 224.2859 611.8408
# Jun 2027       384.0718 281.1995 561.6010 243.2629 714.3816
# Jul 2027       429.4075 307.8706 648.0822 264.0904 844.6746
# Aug 2027       426.1618 305.3732 643.7338 261.8897 839.5674
# Sep 2027       359.6222 264.6982 521.7356 229.4839 659.7581
# Oct 2027       333.0867 247.7890 475.7650 215.7652 594.6897
# Nov 2027       323.6882 241.5148 460.3491 210.5605 573.5935
# Dec 2027       364.0476 266.1867 533.3694 230.1516 679.4804
# Jan 2028       375.1625 272.5298 555.0490 235.0130 712.3748
# Feb 2028       330.4325 244.6898 475.1419 212.6645 596.8612
# Mar 2028       338.1550 249.1293 489.9177 216.0685 618.8853
# Apr 2028       315.1541 234.4600 450.1195 204.1629 562.6046
# May 2028       346.3426 253.4445 506.8227 219.2061 645.0771
# Jun 2028       385.7049 276.7652 581.3902 237.4866 757.0066

# %%
display_png(file="data/EIAelecgen.png")

# %% [markdown]
# ### c.7)
# Eventually, the prediction intervals are so wide that the forecasts are not particularly useful. How many years of forecasts do you think are sufficiently accurate to be usable?
#
# Less than 5 years is the ideal forecast window. Any longer and the model will fail to take into account changes in consumer behavior, technology, government policy, etc

# %%
autoplot(forecast(fit,h=180))
# Out:
# plot without title

# %% [markdown]
# ### D)
#
# #### austourists
#
# nternational Tourists to Australia: Total visitor nights.
# Description
# Quarterly visitor nights (in millions) spent by international tourists to Australia. 1999-2015.
#
# Format
# Quarterly time series of class ts.
#
# Source
# Tourism Research Australia.

# %%
help(austourists)
